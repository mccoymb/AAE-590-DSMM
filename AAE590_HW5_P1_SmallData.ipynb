# %% [markdown]
# <a href="https://colab.research.google.com/github/mccoymb/AAE-590-DSMM/blob/main/AAE590_HW5_P1_SmallData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt


df = pd.read_excel('GeneratedExcel.xlsx', sheet_name='Sheet1')

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat A 5mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material A 5mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Holes 5mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Holed Beam 5mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat B 5mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material B 5mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat B 1mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material B 1mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat A 1mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material A 1mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Holes 1mm']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Stress [MPa]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Holed Beam 1mm Displacement (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat B 100N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material B 100N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat A 100N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material A 100N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Holes 100N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Holed Beam 100N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat B 500N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material B 500N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Mat A 500N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Material A 500N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %%
# Input and Output
X = df[['Volume Fraction']].values
y = df[['Holes 500N']].values

# Normalize
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split for training
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# Build the ANN
model = Sequential([
    Dense(16, input_dim=1, activation='tanh'),
    Dense(32, activation='tanh'),
    Dense(16, activation='tanh'),
    Dense(1, activation='linear')
])

# Compile and train
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=200, batch_size=8, validation_split=0.1, verbose=0)

y_pred_scaled = model.predict(X_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

r_squared = r2_score(y, y_pred)
pearson_r, _ = pearsonr(y.flatten(), y_pred.flatten())

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(X, y, label='Actual Stress', color='blue', alpha=0.6)
plt.scatter(X, y_pred, label='Predicted Stress', color='red', alpha=0.6)
plt.xlabel('Void Coefficient')
plt.ylabel('Displacement [mm]')
plt.title(f'HW 5 P1. Stress vs Volume Fraction of Holed Beam 500N Load (R² = {r_squared:.4f}, Pearson r = {pearson_r:.4f})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
