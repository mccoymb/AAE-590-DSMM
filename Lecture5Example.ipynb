# %% [markdown]
# <a href="https://colab.research.google.com/github/mccoymb/AAE-590-DSMM/blob/main/Lecture5Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats
import pandas as pd
import numpy as np
import pylab
import matplotlib.pyplot as plt
import seaborn as sns

# %%
skewed_dist = stats.loggamma.rvs(5,size = 10000)+5

# %%
normal_dist = np.random.normal(0,1,10000)

# %%
sns.distplot(normal_dist)
print("skewness for the normal distribution ", stats.skew(normal_dist))
# Out:
# <ipython-input-9-17b04bfd1a51>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normal_dist)
# skewness for the normal distribution  0.030320325541386948

# %%
sns.distplot(skewed_dist)
print("skewness for the skewed distribution ", stats.skew(skewed_dist))
# Out:
# <ipython-input-11-fe6dcbe0cb6b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(skewed_dist)
# skewness for the skewed distribution  -0.4935617957846326

# %%
stats.probplot(normal_dist, dist="norm", plot=pylab)
pylab.show()

# %%
stats.probplot(skewed_dist, dist="norm", plot=pylab)
pylab.show()

# %%
skewed_box_cox, lmda = stats.boxcox(skewed_dist)
sns.distplot(skewed_box_cox)
# Out:
# <ipython-input-26-59b2ec822247>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(skewed_box_cox)
# <Axes: ylabel='Density'>

# %%
stats.probplot(skewed_box_cox, dist="norm", plot=pylab)
pylab.show()
print ("Lambda parameter for the Box-Cox Transformation is: ", lmda)
# Out:
# Lambda parameter for the Box-Cox Transformation is:  2.9370062529390006
